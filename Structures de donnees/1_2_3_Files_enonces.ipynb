# %% [markdown]
# <h1><font color="orange"><b>1.2.3.FILES </b></font></h1>
# <hr color="orange">

# %% [markdown]
# ### EXERCICE F1 : Implémenter une file
#
# ---

# %%
class Node:
    def __init__(self,tete,queue):
        self.car=tete
        self.cdr=queue
        
class File:
  
  def __init__(self):
    self.head = None
    self.last = None

  def is_empty(self):
    return self.head == None

  def push(self,el):
    c = Node(el, None)

    if self.head is None:
      self.head = c

    else:
      self.last.cdr = c
    
    self.last = c
    

  def pop(self):

    head = self.head
    if head is not None:
      self.head = head.cdr
    return head

# %% [markdown]
# Tests

# %%
F=File()
F.push(1)
F.push(2)
print(F.head.car)
print(F.last.car)
F.pop()
print(F.head.car)
# Out:
# 1
# 2
# 2

# %% [markdown]
# Visualisation PythonTutor : [ICI](http://pythontutor.com/visualize.html#code=class%20Node%3A%0A%20%20%20%20def%20__init__%28self,v,s%29%3A%0A%20%20%20%20%20%20%20%20self.valeur%3Dv%0A%20%20%20%20%20%20%20%20self.suivant%3Ds%0A%20%20%20%20%20%20%20%20%0Aclass%20File%3A%0A%20%20%22%22%22structure%20de%20file%22%22%22%0A%20%20def%20__init__%28self%29%3A%0A%20%20%20%20self.first%3DNone%0A%20%20%20%20self.last%3DNone%0A%0A%20%20def%20is_empty%28self%29%3A%0A%20%20%20%20return%20self.first%20is%20None%0A%0A%20%20def%20push%28self,el%29%3A%0A%20%20%20%20c%3DNode%28el,None%29%0A%20%20%20%20if%20self.is_empty%28%29%3A%0A%20%20%20%20%20%20self.first%3Dc%0A%20%20%20%20else%3A%0A%20%20%20%20%20%20self.last.suivant%3Dc%0A%20%20%20%20self.last%3Dc%0A%0A%20%20def%20pop%28self%29%3A%0A%20%20%20%20assert%20not%20self.is_empty%28%29,%20'File%20vide'%0A%20%20%20%20v%3Dself.first.valeur%0A%20%20%20%20self.first%3Dself.first.suivant%0A%20%20%20%20if%20self.first%20is%20None%3A%0A%20%20%20%20%20%20self.last%20is%20None%0A%20%20%20%20return%20v%0A%20%20%20%20%0AF%3DFile%28%29%0AF.push%281%29%0AF.push%282%29%0AF.pop%28%29&cumulative=false&curInstr=0&heapPrimitives=nevernest&mode=display&origin=opt-frontend.js&py=3&rawInputLstJSON=%5B%5D&textReferences=false)
